# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# Extracting features of 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]
#as there are 4 tables holding movie data
#for 2018 data

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  NaN
# 4                                                  [5]
# ..                                                 ...
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
# ...

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 270       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 271      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 272  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 273  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 274      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [275 rows x 2 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '552927457b085828308d3b468f6bea5f'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 270       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 271      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 272  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 273  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 274      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# ...

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2020['Cast and crew']
# Out:
# 0      Nicolas Pesce (director/screenplay); Andrea Ri...
# 1      William Eubank (director); Brian Duffield, Ada...
# 2      Miguel Arteta (director); Sam Pitman, Adam Col...
# 3      Jon Avnet (director/screenplay); Eric Nazarian...
# 4      Anthony Jerjen (director); Andrew Crabtree (sc...
#                              ...
# 270    Robert Rodriguez (director/screenplay); Priyan...
# 271    Paul Greengrass (director/screenplay); Luke Da...
# 272    Regina King (director); Kemp Powers (screenpla...
# 273    Emerald Fennell (director/screenplay); Carey M...
# 274    Kornél Mundruczó (director); Kata Wéber (scree...
# Name: Cast and crew, Length: 275, dtype: object

# %%
df_2020['actor_1_name']
# Out:
# 0         Andrea Riseborough
# 1            Kristen Stewart
# 2            Tiffany Haddish
# 3               Richard Gere
# 4              Josh Hartnett
#                ...
# 270    Priyanka Chopra Jonas
# 271                Tom Hanks
# 272        Kingsley Ben-Adir
# 273           Carey Mulligan
# 274            Vanessa Kirby
# Name: actor_1_name, Length: 275, dtype: object

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 270       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 271      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 272  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 273  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 274      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# ...

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 270  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 271   Paul Greengrass              Tom Hanks      Helena Zengel
# 272       Regina King      Kingsley Ben-Adir          Eli Goree
# 273   Emerald Fennell         Carey Mulligan         Bo Burnham
# 274  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                  genres  \
# 0           John Cho                 Horror Mystery Thriller
# 1    Jessica Henwick  Action Horror Science Fiction Thriller
# ...

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      5
# actor_3_name     28
# genres            2
# movie_title       0
# comb             29
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 269       Pete Docter             Jamie Foxx           Tina Fey
# 270  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 272       Regina King      Kingsley Ben-Adir          Eli Goree
# 273   Emerald Fennell         Carey Mulligan         Bo Burnham
# 274  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                  genres  \
# 0           John Cho                 Horror Mystery Thriller
# 1    Jessica Henwick  Action Horror Science Fiction Thriller
# ...

# %%
old_df = pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\mini-project\modular\recommendation_system\data\final_data.csv')

# %%
old_df
# Out:
#       Unnamed: 0       actor_1_name          actor_2_name  \
# 0              0        CCH Pounder      Joel David Moore
# 1              1        Johnny Depp         Orlando Bloom
# 2              2    Christoph Waltz          Rory Kinnear
# 3              3          Tom Hardy        Christian Bale
# 4              4        Doug Walker            Rob Walker
# ...          ...                ...                   ...
# 5871        5873         Will Smith           Tom Holland
# 5872        5874      Saoirse Ronan           Emma Watson
# 5873        5875      George MacKay  Dean-Charles Chapman
# 5874        5876  Michael B. Jordan            Jamie Foxx
# 5875        5877      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                               comb  \
# 0                Wes Studi  CCH Pounder Joel David Moore Wes Studi James C...
# 1           Jack Davenport  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# ...

# %%
final_df = old_df.append(new_df20,ignore_index=True)

# %%
final_df
# Out:
#       Unnamed: 0           actor_1_name      actor_2_name  \
# 0            0.0            CCH Pounder  Joel David Moore
# 1            1.0            Johnny Depp     Orlando Bloom
# 2            2.0        Christoph Waltz      Rory Kinnear
# 3            3.0              Tom Hardy    Christian Bale
# 4            4.0            Doug Walker        Rob Walker
# ...          ...                    ...               ...
# 6117         NaN             Jamie Foxx          Tina Fey
# 6118         NaN  Priyanka Chopra Jonas      Pedro Pascal
# 6119         NaN      Kingsley Ben-Adir         Eli Goree
# 6120         NaN         Carey Mulligan        Bo Burnham
# 6121         NaN          Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                                               comb  \
# 0                Wes Studi  CCH Pounder Joel David Moore Wes Studi James C...
# 1           Jack Davenport  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# ...

# %%
import os
final_df.to_csv(os.path.join(r'C:\Users\HP\OneDrive\Desktop\mini-project\modular\recommendation_system\data','main_data.csv'))

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"

# %%
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df=df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  NaN
# 2                                                  [3]
# 3                                                  [4]
# 4                                                  [5]
# ..                                                 ...
# 353                                                NaN
# 354                                                NaN
# 355                                                NaN
# 356                                                NaN
# 357                                                NaN
#
#                                          Cast and crew   Opening  Opening.1  \
# 0    Roseanne Liang (director/screenplay); Max Land...   JANUARY        1.0
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...   JANUARY       13.0
# ...

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))#calling the function uisng lambda function

# %%
df_2021 = df[['Title','Cast and crew','genres']]

# %%
df_2021
# Out:
#                       Title  \
# 0       Shadow in the Cloud
# 1           The White Tiger
# 2               Locked Down
# 3                   The Dig
# 4          Outside the Wire
# ..                      ...
# 353  The Tragedy of Macbeth
# 354    A Journal for Jordan
# 355       American Underdog
# 356                 Memoria
# 357                     NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 353  Joel Coen (director/screenplay); Denzel Washin...
# 354  Denzel Washington (director); Virgil Williams ...
# 355  Erwin brothers (directors); Jon Erwin, David A...
# 356  Apichatpong Weerasethakul (director/acreenplay...
# ...

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
new_df21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df21
# Out:
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Ramin Bahrani
# 2                                           Doug Liman
# 3                                          Simon Stone
# 4                                      Mikael Håfström
# ..                                                 ...
# 353                                          Joel Coen
# 354                                  Denzel Washington
# 355                                     Erwin brothers
# 356  Apichatpong Weerasethakul (director/acreenplay...
# 357                                                nan
#
#                                           actor_1_name       actor_2_name  \
# 0                                   Chloë Grace Moretz  Taylor John Smith
# 1                                        Adarsh Gourav      Rajkummar Rao
# 2                                        Anne Hathaway   Chiwetel Ejiofor
# ...

# %%
new_df21['comb'] = new_df21['actor_1_name'] + ' ' + new_df21['actor_2_name'] + ' '+ new_df21['actor_3_name'] + ' '+ new_df21['director_name'] +' ' + new_df21['genres']

# %%
new_df21.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     8
# actor_3_name     8
# genres           1
# movie_title      1
# comb             9
# dtype: int64

# %%
new_df21 = new_df21.dropna(how='any')

# %%
new_df21.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df21
# Out:
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Ramin Bahrani
# 2                                           Doug Liman
# 3                                          Simon Stone
# 4                                      Mikael Håfström
# ..                                                 ...
# 352                                     Matthew Vaughn
# 353                                          Joel Coen
# 354                                  Denzel Washington
# 355                                     Erwin brothers
# 356  Apichatpong Weerasethakul (director/acreenplay...
#
#                                           actor_1_name       actor_2_name  \
# 0                                   Chloë Grace Moretz  Taylor John Smith
# 1                                        Adarsh Gourav      Rajkummar Rao
# 2                                        Anne Hathaway   Chiwetel Ejiofor
# ...

# %%
old_df = pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\mini-project\modular\recommendation_system\data\main_data.csv')

# %%
old_df
# Out:
#       Unnamed: 0  Unnamed: 0.1           actor_1_name      actor_2_name  \
# 0              0           0.0            CCH Pounder  Joel David Moore
# 1              1           1.0            Johnny Depp     Orlando Bloom
# 2              2           2.0        Christoph Waltz      Rory Kinnear
# 3              3           3.0              Tom Hardy    Christian Bale
# 4              4           4.0            Doug Walker        Rob Walker
# ...          ...           ...                    ...               ...
# 6117        6117           NaN             Jamie Foxx          Tina Fey
# 6118        6118           NaN  Priyanka Chopra Jonas      Pedro Pascal
# 6119        6119           NaN      Kingsley Ben-Adir         Eli Goree
# 6120        6120           NaN         Carey Mulligan        Bo Burnham
# 6121        6121           NaN          Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                                               comb  \
# ...

# %%
final_df = old_df.append(new_df20,ignore_index=True)

# %%
final_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2964\3022930047.py in <module>
# ----> 1 final_df
#
# NameError: name 'final_df' is not defined

# %%
final_df.to_csv(os.path.join(r'C:\Users\HP\OneDrive\Desktop\mini-project\modular\recommendation_system\data','Final_Data.csv'))
