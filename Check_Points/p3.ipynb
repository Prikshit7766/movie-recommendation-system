# %%
import pandas as pd
import numpy as np

# %% [markdown]
# for 2018 data

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]
#as there are 4 tables holding movie data
#for 2018 data

# %%
df=df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
df
# Out:
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
#
#                                          Cast and crew   Opening  Opening.1  \
# 0    Adam Robitel (director); Leigh Whannell (scree...   JANUARY          5
# 1    Lauren Wolkstein (director); Christopher Radcl...   JANUARY          5
# 2    Simon West (director); Duncan Falconer, Warren...   JANUARY          5
# 3    Warwick Thornton (director); David Tranter, St...   JANUARY         10
# 4    Jaume Collet-Serra (director); Byron Willinger...   JANUARY         12
# ..                                                 ...       ...        ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...  DECEMBER         25
# 268  Adam McKay (director/screenplay); Christian Ba...  DECEMBER         25
# 269  Mimi Leder (director); Daniel Stiepleman (scre...  DECEMBER         25
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...  DECEMBER         25
# 271  David Slade (director); Charlie Brooker (scree...  DECEMBER         28
#
#                                     Production company   Ref.  \
# 0    Universal Pictures / Blumhouse Productions / S...    NaN
# 1                               Vertical Entertainment    NaN
# 2                                    Momentum Pictures    NaN
# 3                                 Samuel Goldwyn Films    NaN
# 4        Lionsgate / StudioCanal / The Picture Company    NaN
# ..                                                 ...    ...
# 267       Columbia Pictures / Gary Sanchez Productions  [164]
# 268          Annapurna Pictures / Plan B Entertainment  [137]
# 269                                     Focus Features  [228]
# 270                                 Annapurna Pictures  [260]
# 271                                            Netflix  [261]
#
#                           Title
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
# [272 rows x 7 columns]

# %%
# information related to genres_list  is missing so we use api to fill genres_list

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '552927457b085828308d3b468f6bea5f'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
result = tmdb_movie.search("The Strange Ones")
movie_id = result[0].id
response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
response.json()
# Out:
# {'adult': False,
#  'backdrop_path': '/vJOG6eOrusXe3CnEGiAVkQp1bXu.jpg',
#  'belongs_to_collection': None,
#  'budget': 0,
#  'genres': [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'name': 'Drama'}],
#  'homepage': 'http://thestrangeones.com/',
#  'id': 426258,
#  'imdb_id': 'tt6014904',
#  'original_language': 'en',
#  'original_title': 'The Strange Ones',
#  'overview': 'Mysterious events surround the travels of two brothers as they make their way across a remote American landscape. On the surface all seems normal, but what appears to be a simple vacation soon gives way to a dark and complex web of secrets. This is the feature film version of the 2011 short film going by the same name.',
#  'popularity': 4.693,
#  'poster_path': '/bbeS9X3xTHrziocOov750LoWmvo.jpg',
#  'production_companies': [{'id': 35562,
#    'logo_path': '/cpeGUCuKo2vgaxzru9RvhJYBcdX.png',
#    'name': 'Gamechanger Films',
#    'origin_country': 'US'},
#   {'id': 87038,
#    'logo_path': '/hn9S9PimxwmeTd0oII6ecurKw2x.png',
#    'name': 'Adastra Films',
#    'origin_country': 'FR'},
#   {'id': 41640,
#    'logo_path': '/e1naE79Djln19oDgMsP3uuvLbTq.png',
#    'name': 'Archer Gray',
#    'origin_country': 'US'},
#   {'id': 73928,
#    'logo_path': None,
#    'name': 'Relic Pictures',
#    'origin_country': 'US'},
#   {'id': 90999,
#    'logo_path': '/fvFryW0HGSIRRtI2hN0hOpTnmhO.png',
#    'name': 'Storyboard Entertainment',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2018-01-05',
#  'revenue': 0,
#  'runtime': 81,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': '',
#  'title': 'The Strange Ones',
#  'video': False,
#  'vote_average': 5.5,
#  'vote_count': 62}

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN
# we are passing title of the movie and w.r.t that it gives the genres  from TMDB

# %% [markdown]
# result = tmdb_movie.search("The Strange Ones")
# movie_id = result[68].id
# response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
# response.json()

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))#calling the function uisng lambda function

# %%
df
# Out:
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
#
#                                          Cast and crew   Opening  Opening.1  \
# 0    Adam Robitel (director); Leigh Whannell (scree...   JANUARY          5
# 1    Lauren Wolkstein (director); Christopher Radcl...   JANUARY          5
# 2    Simon West (director); Duncan Falconer, Warren...   JANUARY          5
# 3    Warwick Thornton (director); David Tranter, St...   JANUARY         10
# 4    Jaume Collet-Serra (director); Byron Willinger...   JANUARY         12
# ..                                                 ...       ...        ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...  DECEMBER         25
# 268  Adam McKay (director/screenplay); Christian Ba...  DECEMBER         25
# 269  Mimi Leder (director); Daniel Stiepleman (scre...  DECEMBER         25
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...  DECEMBER         25
# 271  David Slade (director); Charlie Brooker (scree...  DECEMBER         28
#
#                                     Production company   Ref.  \
# 0    Universal Pictures / Blumhouse Productions / S...    NaN
# 1                               Vertical Entertainment    NaN
# 2                                    Momentum Pictures    NaN
# 3                                 Samuel Goldwyn Films    NaN
# 4        Lionsgate / StudioCanal / The Picture Company    NaN
# ..                                                 ...    ...
# 267       Columbia Pictures / Gary Sanchez Productions  [164]
# 268          Annapurna Pictures / Plan B Entertainment  [137]
# 269                                     Focus Features  [228]
# 270                                 Annapurna Pictures  [260]
# 271                                            Netflix  [261]
#
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
#                                               genres
# 0                            Horror Mystery Thriller
# 1                                     Thriller Drama
# 2                                    Action Thriller
# 3                              Drama History Western
# 4                            Action Thriller Mystery
# ..                                               ...
# 267                   Mystery Adventure Comedy Crime
# 268        Thriller Science Fiction Action Adventure
# 269                                    Drama History
# 270                      Thriller Crime Drama Action
# 271  Science Fiction Mystery Drama Thriller TV Movie
#
# [272 rows x 8 columns]

# %%
df_2018 = df[['Title','Cast and crew','genres']]

# %%
df_2018.head()
# Out:
#                     movie_title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 271  David Slade (director); Charlie Brooker (scree...
#
#                                               genres       director_name  \
# 0                            Horror Mystery Thriller        Adam Robitel
# 1                                     Thriller Drama    Lauren Wolkstein
# 2                                    Action Thriller          Simon West
# 3                              Drama History Western    Warwick Thornton
# 4                            Action Thriller Mystery  Jaume Collet-Serra
# ..                                               ...                 ...
# 267                   Mystery Adventure Comedy Crime          Etan Cohen
# 268        Thriller Science Fiction Action Adventure          Adam McKay
# 269                                    Drama History          Mimi Leder
# 270                      Thriller Crime Drama Action        Karyn Kusama
# 271  Science Fiction Mystery Drama Thriller TV Movie         David Slade
#
#         actor_1_name            actor_2_name    actor_3_name
# 0          Lin Shaye           Angus Sampson  Leigh Whannell
# 1      Alex Pettyfer  James Freedson-Jackson   Emily Althaus
# 2     Dominic Cooper          Austin Stowell      Gemma Chan
# 3        Bryan Brown               Sam Neill             NaN
# 4        Liam Neeson            Vera Farmiga  Patrick Wilson
# ..               ...                     ...             ...
# 267     Will Ferrell          John C. Reilly    Rebecca Hall
# 268   Christian Bale               Amy Adams    Steve Carell
# 269   Felicity Jones            Armie Hammer  Justin Theroux
# 270    Nicole Kidman          Sebastian Stan    Toby Kebbell
# 271  Fionn Whitehead            Will Poulter   Asim Chaudhry
#
# [272 rows x 7 columns]

# %%
df["Cast and crew"]
# Out:
# 0      Adam Robitel (director); Leigh Whannell (scree...
# 1      Lauren Wolkstein (director); Christopher Radcl...
# 2      Simon West (director); Duncan Falconer, Warren...
# 3      Warwick Thornton (director); David Tranter, St...
# 4      Jaume Collet-Serra (director); Byron Willinger...
#                              ...
# 267    Etan Cohen (director/screenplay); Will Ferrell...
# 268    Adam McKay (director/screenplay); Christian Ba...
# 269    Mimi Leder (director); Daniel Stiepleman (scre...
# 270    Karyn Kusama (director); Phil Hay, Matt Manfre...
# 271    David Slade (director); Charlie Brooker (scree...
# Name: Cast and crew, Length: 272, dtype: object

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
   
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2018['director_name']
# Out:
# 0            Adam Robitel
# 1        Lauren Wolkstein
# 2              Simon West
# 3        Warwick Thornton
# 4      Jaume Collet-Serra
#               ...
# 267            Etan Cohen
# 268            Adam McKay
# 269            Mimi Leder
# 270          Karyn Kusama
# 271           David Slade
# Name: director_name, Length: 272, dtype: object

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 271  David Slade (director); Charlie Brooker (scree...
#
#                                               genres       director_name  \
# 0                            Horror Mystery Thriller        Adam Robitel
# 1                                     Thriller Drama    Lauren Wolkstein
# 2                                    Action Thriller          Simon West
# 3                              Drama History Western    Warwick Thornton
# 4                            Action Thriller Mystery  Jaume Collet-Serra
# ..                                               ...                 ...
# 267                   Mystery Adventure Comedy Crime          Etan Cohen
# 268        Thriller Science Fiction Action Adventure          Adam McKay
# 269                                    Drama History          Mimi Leder
# 270                      Thriller Crime Drama Action        Karyn Kusama
# 271  Science Fiction Mystery Drama Thriller TV Movie         David Slade
#
#         actor_1_name            actor_2_name    actor_3_name
# 0          Lin Shaye           Angus Sampson  Leigh Whannell
# 1      Alex Pettyfer  James Freedson-Jackson   Emily Althaus
# 2     Dominic Cooper          Austin Stowell      Gemma Chan
# 3        Bryan Brown               Sam Neill             NaN
# 4        Liam Neeson            Vera Farmiga  Patrick Wilson
# ..               ...                     ...             ...
# 267     Will Ferrell          John C. Reilly    Rebecca Hall
# 268   Christian Bale               Amy Adams    Steve Carell
# 269   Felicity Jones            Armie Hammer  Justin Theroux
# 270    Nicole Kidman          Sebastian Stan    Toby Kebbell
# 271  Fionn Whitehead            Will Poulter   Asim Chaudhry
#
# [272 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 267          Etan Cohen     Will Ferrell          John C. Reilly
# 268          Adam McKay   Christian Bale               Amy Adams
# 269          Mimi Leder   Felicity Jones            Armie Hammer
# 270        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 271         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# 1     Emily Althaus                                   Thriller Drama
# 2        Gemma Chan                                  Action Thriller
# 3               NaN                            Drama History Western
# 4    Patrick Wilson                          Action Thriller Mystery
# ..              ...                                              ...
# 267    Rebecca Hall                   Mystery Adventure Comedy Crime
# 268    Steve Carell        Thriller Science Fiction Action Adventure
# 269  Justin Theroux                                    Drama History
# 270    Toby Kebbell                      Thriller Crime Drama Action
# 271   Asim Chaudhry  Science Fiction Mystery Drama Thriller TV Movie
#
#                     movie_title
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
# [272 rows x 6 columns]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 267          Etan Cohen     Will Ferrell          John C. Reilly
# 268          Adam McKay   Christian Bale               Amy Adams
# 269          Mimi Leder   Felicity Jones            Armie Hammer
# 270        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 271         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# 1     Emily Althaus                                   Thriller Drama
# 2        Gemma Chan                                  Action Thriller
# 3           unknown                            Drama History Western
# 4    Patrick Wilson                          Action Thriller Mystery
# ..              ...                                              ...
# 267    Rebecca Hall                   Mystery Adventure Comedy Crime
# 268    Steve Carell        Thriller Science Fiction Action Adventure
# 269  Justin Theroux                                    Drama History
# 270    Toby Kebbell                      Thriller Crime Drama Action
# 271   Asim Chaudhry  Science Fiction Mystery Drama Thriller TV Movie
#
#                     movie_title  \
# 0       insidious: the last key
# 1              the strange ones
# 2                      stratton
# 3                 sweet country
# 4                  the commuter
# ..                          ...
# 267             holmes & watson
# 268                        vice
# 269         on the basis of sex
# 270                   destroyer
# 271  black mirror: bandersnatch
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 267  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 268  Christian Bale Amy Adams Steve Carell Adam McK...
# 269  Felicity Jones Armie Hammer Justin Theroux Mim...
# 270  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 271  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [272 rows x 7 columns]

# %% [markdown]
# for 2019 dataset

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df=df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1              Title  \
# 0     JANUARY          4        Escape Room
# 1     JANUARY          4         Rust Creek
# 2     JANUARY          4   American Hangman
# 3     JANUARY         11   A Dog's Way Home
# 4     JANUARY         11         The Upside
# ..        ...        ...                ...
# 237  DECEMBER         25  Spies in Disguise
# 238  DECEMBER         25       Little Women
# 239  DECEMBER         25               1917
# 240  DECEMBER         25         Just Mercy
# 241  DECEMBER         27           Clemency
#
#                                     Production company  \
# 0                    Columbia Pictures / Original Film
# 1                                            IFC Films
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# 237  20th Century Fox / Blue Sky Studios / Chernin ...
# 238            Columbia Pictures / Regency Enterprises
# 239           Universal Pictures / DreamWorks Pictures
# 240          Warner Bros. Pictures / Participant Media
# 241                                               Neon
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1    Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2    Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3    Charles Martin Smith (director); W. Bruce Came...    [5]
# 4    Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                 ...    ...
# 237  Nick Bruno, Troy Quane (directors); Brad Copel...  [132]
# 238  Greta Gerwig (director/screenplay); Saoirse Ro...  [221]
# 239  Sam Mendes (director/screenplay); Krysty Wilso...  [222]
# 240  Destin Daniel Cretton (director/screenplay), A...  [223]
# 241  Chinonye Chukwu (director/screenplay); Alfre W...  [224]
#
# [242 rows x 6 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))#calling the function uisng lambda function

# %%
df_2019 = df[['Title','Cast and crew','genres']]

# %%
df_2019
# Out:
#                  Title                                      Cast and crew  \
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 237  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 238       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 239               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 240         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 241           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                        genres
# 0                     Horror Thriller Mystery
# 1                              Thriller Drama
# 2                                    Thriller
# 3                      Drama Adventure Family
# 4                                Comedy Drama
# ..                                        ...
# 237  Animation Action Adventure Comedy Family
# 238                             Drama Romance
# 239                 War Drama Action Thriller
# 240                       Drama Crime History
# 241                                     Drama
#
# [242 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#               director_name         actor_1_name          actor_2_name  \
# 0              Adam Robitel       Taylor Russell          Logan Miller
# 1               Jen McGowan    Hermione Corfield           Jay Paulson
# 2         Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3      Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4               Neil Burger       Bryan Cranston            Kevin Hart
# ..                      ...                  ...                   ...
# 237  Nick Bruno, Troy Quane           Will Smith           Tom Holland
# 238            Greta Gerwig        Saoirse Ronan           Emma Watson
# 239              Sam Mendes        George MacKay  Dean-Charles Chapman
# 240   Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 241         Chinonye Chukwu        Alfre Woodard        Wendell Pierce
#
#          actor_3_name                                    genres  \
# 0    Deborah Ann Woll                   Horror Thriller Mystery
# 1        Sean O'Bryan                            Thriller Drama
# 2       Oliver Dennis                                  Thriller
# 3     Alexandra Shipp                    Drama Adventure Family
# 4       Nicole Kidman                              Comedy Drama
# ..                ...                                       ...
# 237     Rashida Jones  Animation Action Adventure Comedy Family
# 238     Florence Pugh                             Drama Romance
# 239       Mark Strong                 War Drama Action Thriller
# 240       Brie Larson                       Drama Crime History
# 241       Aldis Hodge                                     Drama
#
#            movie_title                                               comb
# 0          escape room  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1           rust creek  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2     american hangman  Donald Sutherland Vincent Kartheiser Oliver De...
# 3     a dog's way home  Bryce Dallas Howard Edward James Olmos Alexand...
# 4           the upside  Bryan Cranston Kevin Hart Nicole Kidman Neil B...
# ..                 ...                                                ...
# 237  spies in disguise  Will Smith Tom Holland Rashida Jones Nick Brun...
# 238       little women  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 239               1917  George MacKay Dean-Charles Chapman Mark Strong...
# 240         just mercy  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 241           clemency  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [242 rows x 7 columns]

# %%
my_df = new_df18.append(new_df19,ignore_index=True)

# %%
my_df
# Out:
#               director_name       actor_1_name            actor_2_name  \
# 0              Adam Robitel          Lin Shaye           Angus Sampson
# 1          Lauren Wolkstein      Alex Pettyfer  James Freedson-Jackson
# 2                Simon West     Dominic Cooper          Austin Stowell
# 3          Warwick Thornton        Bryan Brown               Sam Neill
# 4        Jaume Collet-Serra        Liam Neeson            Vera Farmiga
# ..                      ...                ...                     ...
# 509  Nick Bruno, Troy Quane         Will Smith             Tom Holland
# 510            Greta Gerwig      Saoirse Ronan             Emma Watson
# 511              Sam Mendes      George MacKay    Dean-Charles Chapman
# 512   Destin Daniel Cretton  Michael B. Jordan              Jamie Foxx
# 513         Chinonye Chukwu      Alfre Woodard          Wendell Pierce
#
#        actor_3_name                                    genres  \
# 0    Leigh Whannell                   Horror Mystery Thriller
# 1     Emily Althaus                            Thriller Drama
# 2        Gemma Chan                           Action Thriller
# 3           unknown                     Drama History Western
# 4    Patrick Wilson                   Action Thriller Mystery
# ..              ...                                       ...
# 509   Rashida Jones  Animation Action Adventure Comedy Family
# 510   Florence Pugh                             Drama Romance
# 511     Mark Strong                 War Drama Action Thriller
# 512     Brie Larson                       Drama Crime History
# 513     Aldis Hodge                                     Drama
#
#                  movie_title  \
# 0    insidious: the last key
# 1           the strange ones
# 2                   stratton
# 3              sweet country
# 4               the commuter
# ..                       ...
# 509        spies in disguise
# 510             little women
# 511                     1917
# 512               just mercy
# 513                 clemency
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 509  Will Smith Tom Holland Rashida Jones Nick Brun...
# 510  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 511  George MacKay Dean-Charles Chapman Mark Strong...
# 512  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 513  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [514 rows x 7 columns]

# %%
old_df = pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\mini-project\modular\recommendation_system\data\new_data.csv')

# %%
old_df
# Out:
#       Unnamed: 0  Unnamed: 0.1          director_name          actor_1_name  \
# 0              0           0.0          James Cameron           CCH Pounder
# 1              1           1.0         Gore Verbinski           Johnny Depp
# 2              2           2.0             Sam Mendes       Christoph Waltz
# 3              3           3.0      Christopher Nolan             Tom Hardy
# 4              4           4.0            Doug Walker           Doug Walker
# ...          ...           ...                    ...                   ...
# 5359         524           NaN            Jim Strouse      Jessica Williams
# 5360         525           NaN            Farhad Mann         Adelaide Kane
# 5361         526           NaN       Hannaleena Hauru        Inka Haapamäki
# 5362         527           NaN  Jonathan A. Rosenbaum  Lou Diamond Phillips
# 5363         529           NaN           Ravi Udyawar        Sridevi Kapoor
#
#                 actor_2_name          actor_3_name  \
# 0           Joel David Moore             Wes Studi
# 1              Orlando Bloom        Jack Davenport
# 2               Rory Kinnear      Stephanie Sigman
# 3             Christian Bale  Joseph Gordon-Levitt
# 4                 Rob Walker               unknown
# ...                      ...                   ...
# 5359            Chris O'Dowd       Keith Stanfield
# 5360  Benjamin Hollingsworth     Jean Louisa Kelly
# 5361           Rosa Honkonen        Tiitus Rantala
# 5362           Wallace Shawn           Gina Holden
# 5363               Sajal Ali        Akshaye Khanna
#
#                                genres  \
# 0     Action Adventure Fantasy Sci-Fi
# 1            Action Adventure Fantasy
# 2           Action Adventure Thriller
# 3                     Action Thriller
# 4                         Documentary
# ...                               ...
# 5359                   Romance Comedy
# 5360                          Romance
# 5361                   Romance Comedy
# 5362       Crime Comedy Action Family
# 5363             Crime Drama Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5359                       the incredible jessica james
# 5360                                  can't buy my love
# 5361                   thick lashes of lauri mäntyvaara
# 5362                        cop and a half: new recruit
# 5363                                                mom
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5359  Jessica Williams Chris O'Dowd Keith Stanfield ...
# 5360  Adelaide Kane Benjamin Hollingsworth Jean Loui...
# 5361  Inka Haapamäki Rosa Honkonen Tiitus Rantala Ha...
# 5362  Lou Diamond Phillips Wallace Shawn Gina Holden...
# 5363  Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi U...
#
# [5364 rows x 9 columns]

# %%
final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#       Unnamed: 0  Unnamed: 0.1       actor_1_name          actor_2_name  \
# 0            0.0           0.0        CCH Pounder      Joel David Moore
# 1            1.0           1.0        Johnny Depp         Orlando Bloom
# 2            2.0           2.0    Christoph Waltz          Rory Kinnear
# 3            3.0           3.0          Tom Hardy        Christian Bale
# 4            4.0           4.0        Doug Walker            Rob Walker
# ...          ...           ...                ...                   ...
# 5873         NaN           NaN         Will Smith           Tom Holland
# 5874         NaN           NaN      Saoirse Ronan           Emma Watson
# 5875         NaN           NaN      George MacKay  Dean-Charles Chapman
# 5876         NaN           NaN  Michael B. Jordan            Jamie Foxx
# 5877         NaN           NaN      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                               comb  \
# 0                Wes Studi  CCH Pounder Joel David Moore Wes Studi James C...
# 1           Jack Davenport  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2         Stephanie Sigman  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Joseph Gordon-Levitt  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4                  unknown  Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                    ...                                                ...
# 5873         Rashida Jones  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5874         Florence Pugh  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5875           Mark Strong  George MacKay Dean-Charles Chapman Mark Strong...
# 5876           Brie Larson  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5877           Aldis Hodge  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
#                director_name                                    genres  \
# 0              James Cameron           Action Adventure Fantasy Sci-Fi
# 1             Gore Verbinski                  Action Adventure Fantasy
# 2                 Sam Mendes                 Action Adventure Thriller
# 3          Christopher Nolan                           Action Thriller
# 4                Doug Walker                               Documentary
# ...                      ...                                       ...
# 5873  Nick Bruno, Troy Quane  Animation Action Adventure Comedy Family
# 5874            Greta Gerwig                             Drama Romance
# 5875              Sam Mendes                 War Drama Action Thriller
# 5876   Destin Daniel Cretton                       Drama Crime History
# 5877         Chinonye Chukwu                                     Drama
#
#                                             movie_title
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5873                                  spies in disguise
# 5874                                       little women
# 5875                                               1917
# 5876                                         just mercy
# 5877                                           clemency
#
# [5878 rows x 9 columns]

# %%
final_df.isna().sum()
# Out:
# Unnamed: 0       514
# Unnamed: 0.1     972
# actor_1_name       0
# actor_2_name       0
# actor_3_name       0
# comb               2
# director_name      0
# genres             2
# movie_title        0
# dtype: int64

# %%
final_df=final_df.drop("Unnamed: 0",axis=1)

# %%
final_df=final_df.drop("Unnamed: 0.1",axis=1)

# %%
final_df
# Out:
#            actor_1_name          actor_2_name          actor_3_name  \
# 0           CCH Pounder      Joel David Moore             Wes Studi
# 1           Johnny Depp         Orlando Bloom        Jack Davenport
# 2       Christoph Waltz          Rory Kinnear      Stephanie Sigman
# 3             Tom Hardy        Christian Bale  Joseph Gordon-Levitt
# 4           Doug Walker            Rob Walker               unknown
# ...                 ...                   ...                   ...
# 5873         Will Smith           Tom Holland         Rashida Jones
# 5874      Saoirse Ronan           Emma Watson         Florence Pugh
# 5875      George MacKay  Dean-Charles Chapman           Mark Strong
# 5876  Michael B. Jordan            Jamie Foxx           Brie Larson
# 5877      Alfre Woodard        Wendell Pierce           Aldis Hodge
#
#                                                    comb  \
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5873  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5874  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5875  George MacKay Dean-Charles Chapman Mark Strong...
# 5876  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5877  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
#                director_name                                    genres  \
# 0              James Cameron           Action Adventure Fantasy Sci-Fi
# 1             Gore Verbinski                  Action Adventure Fantasy
# 2                 Sam Mendes                 Action Adventure Thriller
# 3          Christopher Nolan                           Action Thriller
# 4                Doug Walker                               Documentary
# ...                      ...                                       ...
# 5873  Nick Bruno, Troy Quane  Animation Action Adventure Comedy Family
# 5874            Greta Gerwig                             Drama Romance
# 5875              Sam Mendes                 War Drama Action Thriller
# 5876   Destin Daniel Cretton                       Drama Crime History
# 5877         Chinonye Chukwu                                     Drama
#
#                                             movie_title
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5873                                  spies in disguise
# 5874                                       little women
# 5875                                               1917
# 5876                                         just mercy
# 5877                                           clemency
#
# [5878 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# comb             2
# director_name    0
# genres           2
# movie_title      0
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# comb             0
# director_name    0
# genres           0
# movie_title      0
# dtype: int64

# %%
import os
final_df.to_csv(os.path.join(r'C:\Users\HP\OneDrive\Desktop\mini-project\modular\recommendation_system\data','final_data.csv'))
